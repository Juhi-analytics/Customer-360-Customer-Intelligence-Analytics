# %% [markdown]
# # Customer 360 Analytics Platform
#
# ## Notebook 05 – RFM Analysis
#
# ### Objective
#
# Perform RFM (Recency, Frequency, Monetary) analysis to segment customers based on their purchasing behavior. This notebook identifies high-value, loyal, and at-risk customers to support targeted marketing and customer retention strategies.
#
# ### Business Questions
#
# - Which customers purchased most recently?
# - Which customers purchase most frequently?
# - Which customers spend the most?
# - Who are the Champions and Loyal Customers?
# - Which customers are at risk of churn?
# - How can marketing campaigns be personalized for different customer segments?
#
# ### Tools Used
#
# - Python
# - Pandas
# - Matplotlib
#
# ### Output
#
# - RFM Table
# - Customer Segments
# - RFM Scores
# - Charts for Power BI

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

pd.set_option("display.max_columns", None)
