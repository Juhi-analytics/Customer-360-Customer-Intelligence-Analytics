# %% [markdown]
# Customer360 Analytics
#
# Notebook 1
#
# 1. Project Introduction
#
# 2. Import Libraries
#
# 3. Configure Pandas
#
# 4. Define Project Paths
#
# 5. Load Datasets
#
# 6. Verify Data Loading
#
# 7. Explore Data
#
# 8. Understand Dataset Structure
#
# 9. Initial Quality Assessment
#
# 10. Summary

# %% [markdown]
# # Customer 360 Analytics Platform
#
# ## Notebook 01: Data Loading
#
# ### Objective
#
# The objective of this notebook is to load the Olist Brazilian E-Commerce datasets into pandas DataFrames and perform an initial exploration of the data.
#
# ### Dataset
#
# - Customers
# - Orders
# - Order Items
# - Payments
# - Reviews
#
# ### Goals
#
# - Import datasets
# - Verify successful loading
# - Inspect data structure
# - Understand dimensions
# - Identify initial data quality issues

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Display all columns
pd.set_option("display.max_columns", None)

# Display wider tables
pd.set_option("display.width", 120)

# Show numbers with two decimal places
pd.set_option("display.float_format", "{:.2f}".format)

# %%
BASE_DIR = Path.cwd().parent
DATA_DIR = BASE_DIR / "Data"

print("Project Folder :", BASE_DIR)
print("Data Folder    :", DATA_DIR)
# Out:
# Project Folder : d:\360 Analytics project
# Data Folder    : d:\360 Analytics project\Data

# %%
csv_files = list(DATA_DIR.glob("*.csv"))

print("Datasets Found:")

for file in csv_files:
    print(file.name)
# Out:
# Datasets Found:
# olist_customers_dataset.csv
# olist_geolocation_dataset.csv
# olist_orders_dataset.csv
# olist_order_items_dataset.csv
# olist_order_payments_dataset.csv
# olist_order_reviews_dataset.csv
# olist_products_dataset.csv
# olist_sellers_dataset.csv

# %%
customers = pd.read_csv(
    DATA_DIR / "olist_customers_dataset.csv"
)

print("Customers Loaded Successfully")
# Out:
# Customers Loaded Successfully

# %%
orders = pd.read_csv(
    DATA_DIR / "olist_orders_dataset.csv"
)

print("Orders Loaded Successfully")
# Out:
# Orders Loaded Successfully

# %%
order_items = pd.read_csv(
    DATA_DIR / "olist_order_items_dataset.csv"
)

print("Order Items Loaded Successfully")
# Out:
# Order Items Loaded Successfully

# %%
payments = pd.read_csv(
    DATA_DIR / "olist_order_payments_dataset.csv"
)

print("Payments Loaded Successfully")
# Out:
# Payments Loaded Successfully

# %%
reviews = pd.read_csv(
    DATA_DIR / "olist_order_reviews_dataset.csv"
)

print("Reviews Loaded Successfully")
# Out:
# Reviews Loaded Successfully

# %%
datasets = {
    "Customers": customers,
    "Orders": orders,
    "Order Items": order_items,
    "Payments": payments,
    "Reviews": reviews
}

for name, df in datasets.items():
    print(f"{name} loaded successfully.")
# Out:
# Customers loaded successfully.
# Orders loaded successfully.
# Order Items loaded successfully.
# Payments loaded successfully.
# Reviews loaded successfully.

# %%
for name, df in datasets.items():
    print(f"{name}: {df.shape}")
# Out:
# Customers: (99441, 5)
# Orders: (99441, 8)
# Order Items: (112650, 7)
# Payments: (103886, 5)
# Reviews: (99224, 7)

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  customer_zip_code_prefix  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0                     14409
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3                      9790
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c                      8775
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066                     13056
#
#            customer_city customer_state
# 0                 franca             SP
# 1  sao bernardo do campo             SP
# 2              sao paulo             SP
# 3        mogi das cruzes             SP
# 4               campinas             SP

# %%
orders.head()
# Out:
#                            order_id                       customer_id order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef    delivered      2018-07-24 20:41:37
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089    delivered      2018-08-08 08:38:49
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82    delivered      2017-11-18 19:28:06
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c    delivered      2018-02-13 21:18:39
#
#      order_approved_at order_delivered_carrier_date order_delivered_customer_date order_estimated_delivery_date
# 0  2017-10-02 11:07:15          2017-10-04 19:55:00           2017-10-10 21:25:13           2017-10-18 00:00:00
# ...

# %%
order_items.head()
# Out:
#                            order_id  order_item_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3              1  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e              1  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75              1  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1  ac6c3623068f30de03045865e4e10089
#
#                           seller_id  shipping_limit_date  price  freight_value
# 0  48436dade18ac8b2bce089ec2a041202  2017-09-19 09:45:35  58.90          13.29
# 1  dd7ddc04e1b6c2c614352b383efe2d36  2017-05-03 11:05:13 239.90          19.93
# 2  5b51032eddd242adc84c38acab88f23d  2018-01-18 14:48:30 199.00          17.87
# 3  9d7a1d34a5052409006425275ba1c2b4  2018-08-15 10:10:18  12.99          12.79
# ...

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  payment_installments  payment_value
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card                     8          99.33
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card                     1          24.39
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card                     1          65.71
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card                     8         107.78
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card                     2         128.45

# %%
reviews.head()
# Out:
#                           review_id                          order_id  review_score review_comment_title  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb             4                  NaN
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33             5                  NaN
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b             5                  NaN
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b             5                  NaN
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1             5                  NaN
#
#                               review_comment_message review_creation_date review_answer_timestamp
# 0                                                NaN  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1                                                NaN  2018-03-10 00:00:00     2018-03-11 03:05:13
# ...

# %%
for name, df in datasets.items():
    print("=" * 60)
    print(name)
    print("=" * 60)
    df.info()
    print("\n")
# Out:
# ...
# Customers
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  str
#  1   customer_unique_id        99441 non-null  str
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 3.8 MB
#
#
# ...
# Orders
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
# ...

# %%
payments.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count           103886.00             103886.00      103886.00
# mean                 1.09                  2.85         154.10
# std                  0.71                  2.69         217.49
# min                  1.00                  0.00           0.00
# 25%                  1.00                  1.00          56.79
# 50%                  1.00                  1.00         100.00
# 75%                  1.00                  4.00         171.84
# max                 29.00                 24.00       13664.08

# %%
order_items.describe()
# Out:
#        order_item_id     price  freight_value
# count      112650.00 112650.00      112650.00
# mean            1.20    120.65          19.99
# std             0.71    183.63          15.81
# min             1.00      0.85           0.00
# 25%             1.00     39.90          13.08
# 50%             1.00     74.99          16.26
# 75%             1.00    134.90          21.15
# max            21.00   6735.00         409.68

# %%
for name, df in datasets.items():
    print(f"\n{name}")
    print(df.columns.tolist())
# Out:
# Customers
# ['customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
#
# Orders
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
#
# Order Items
# ['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value']
#
# Payments
# ['order_id', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']
#
# Reviews
# ['review_id', 'order_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp']

# %% [markdown]
# # Initial Observations
#
# ## Customers
# - Contains customer identifiers and location information.
#
# ## Orders
# - Stores order lifecycle timestamps and order status.
#
# ## Order Items
# - Contains product-level details for each order.
#
# ## Payments
# - Records payment methods and transaction values.
#
# ## Reviews
# - Contains customer review scores and comments.
#
# These datasets together provide a complete view of customer purchases and will be integrated during later stages of analysis.
